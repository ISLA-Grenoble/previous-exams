# %% [markdown]
# # Part 2: Multiple Choice Questions
#
# For each question, select the letter corresponding to the correct answer and provide a brief justification.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Question 1
#
# **Question:**
#
# - (A)
# - (B)
# - (C)
# - (D)
#
# **Answer:**
#
# **Justification:**

# %% [markdown]
# ### Question 2
#
# **Question:**
#
# - (A)
# - (B)
# - (C)
# - (D)
#
# **Answer:**
#
# **Justification:**

# %% [markdown]
# ### Question 3
#
# **Question:**
#
# - (A)
# - (B)
# - (C)
# - (D)
#
# **Answer:**
#
# **Justification:**

# %% [markdown]
# ### Question 4
#
# **Question:**
#
# - (A)
# - (B)
# - (C)
# - (D)
#
# **Answer:**
#
# **Justification:**

# %% [markdown]
# ### Question 5
#
# **Question:**
#
# - (A)
# - (B)
# - (C)
# - (D)
#
# **Answer:**
#
# **Justification:**
