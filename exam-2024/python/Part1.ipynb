# %% [markdown]
# # Part 1: True/False Questions
#
# Answer each statement with **True** or **False** and provide a brief justification.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Question (a)
#
# **Statement:** Unlabeled data can be used for detecting overfitting.
#
# **Answer (True / False):**
#
# **Justification:**

# %% [markdown]
# ### Question (b)
#
# **Statement:** PCA and spectral embedding perform eigendecomposition on two different matrices. However, the dimensions of these matrices are the same.
#
# **Answer (True / False):**
#
# **Justification:**

# %% [markdown]
# ### Question (c)
#
# **Statement:** Since classification is a special case of regression, logistic regression is a special case of linear regression.
#
# **Answer (True / False):**
#
# **Justification:**

# %% [markdown]
# ### Question (d)
#
# **Statement:** The largest eigenvector of the covariance matrix is the direction of minimum variance in the data.
#
# **Answer (True / False):**
#
# **Justification:**

# %% [markdown]
# ### Question (e)
#
# **Statement:** A random forest is an ensemble learning method that attempts to lower the bias error of decision trees.
#
# **Answer (True / False):**
#
# **Justification:**

# %% [markdown]
# ### Question (f)
#
# **Statement:** As model complexity increases, bias will decrease while variance will increase.
#
# **Answer (True / False):**
#
# **Justification:**

# %% [markdown]
# ### Question (g)
#
# **Statement:** Consider a cancer diagnosis classification problem where almost all of the people being diagnosed don't have cancer. The probability of correct classification is the most important metric to optimize.
#
# **Answer (True / False):**
#
# **Justification:**

# %% [markdown]
# ### Question (h)
#
# **Statement:** The more features that we use to represent our data, the better the learning algorithm will generalize to new data points.
#
# **Answer (True / False):**
#
# **Justification:**

# %% [markdown]
# ## Q2 — Ridge regularization
#
# Assume N training samples (x₁, y₁), …, (xN, yN) where xᵢ ∈ Rᵖ and yᵢ ∈ R. For λ ≥ 0, consider:
#
# L_λ(β) = (1/N) Σᵢ₌₁ᴺ (yᵢ − xᵢᵀβ)² + λ‖β‖²₂
#
# and let C_λ = min_{β} L_λ(β). Which statement is true?
# - (A) C_λ is a non-increasing function of λ.
# - (B) For λ = 0, the loss L₀ is non-convex and might have several minimizers.
# - (C) C_λ is a non-decreasing function of λ.
# - (D) None of the above statements are true.
#
# **Answer:**

# %% [markdown]
# ## Q3 — k-nearest neighbors
#
# Which of the following are true for the k-nearest neighbor (k-NN) algorithm?
# - (A) k-NN can be used for both classification and regression.
# - (B) The decision boundary looks smoother with smaller values of k.
# - (C) As k increases, the variance usually increases.
# - (D) None of the above.
#
# **Answer:**
