# %% [markdown]
# **Q1.** Given $d$-dimensional data $x_{i=1}^N$, you run PCA and pick $P$ principal components. Can you always reconstruct any data point $x_i$ from the $P$ principal components with zero reconstruction error?
# - (A) Yes, if $P < d$.
# - (B) Yes, if $P = d$.
# - (C) Yes, if $P < N$.
# - (D) No, always.

# %% [markdown]
# **Q2.** Which of the following transformations to a data matrix X will affect the principal components obtained through PCA?
# - (A) Adding a constant value to all elements of X.
# - (B) Multiplying one of the features of X by a constant. CHOSEN, GOOD
# - (C) Adding an extra feature to X (an extra column) that is constant across all data points.
# - (D) None of the above answers.

# %% [markdown]
# **Q3.** In linear regression, we model $p(y \mid x) \sim \mathcal{N}(\beta^\top x + \beta_0, \sigma^2)$. The irreducible error in this model is:
# - (A) $\sigma^2$
# - (B) $E[y \mid x]$
# - (C) $E[(y - E[y \mid x])^2 \mid x]$
# - (D) None of the above.

# %% [markdown]
# **Q4.** The decision boundaries of a logistic regression model:
# - (A) Split classes using only one of the input features.
# - (B) Split classes using a combination of the input features.
# - (C) Often have curved shapes.
# - (D) None of the above.

# %% [markdown]
# **Q5.** How does the bias-variance decomposition of a ridge regression estimator compare with that of ordinary least squares regression?
# - (A) Ridge has larger bias, larger variance.
# - (B) Ridge has larger bias, smaller variance.
# - (C) Ridge has smaller bias, larger variance.
# - (D) Ridge has smaller bias, smaller variance.

# %% [markdown]
# **Q6.** Suppose you want to split a graph G into two subgraphs. Let L be G's Laplacian matrix. Which of the following could help you find a good split?
# - (A) The eigenvector corresponding to the second-largest eigenvalue of L.
# - (B) The eigenvector corresponding to the second-smallest eigenvalue of L.
# - (C) The left singular vector corresponding to the second-largest singular value of L.
# - (D) None of the above.

# %% [markdown]
# **Q7.** We define a 2-dimensional dataset and process it using `StandardScaler` from `sklearn` with its default parameters. The dataset has feature X1 centered around 4 with unit variance and feature X2 uniformly spread around 0 with larger variance. Which of the four presented preprocessings (A, B, C, D — shown in the figure in the exam PDF) results from applying `StandardScaler`?
# - (A) Preprocessing A
# - (B) Preprocessing B
# - (C) Preprocessing C
# - (D) Preprocessing D

# %% [markdown]
# **Q8.** Why does random forests select a random subset of predictors when building each of its decision trees?
# - (A) To facilitate the cross-validation procedure afterwards.
# - (B) To reduce bias of the final ensemble estimator.
# - (C) To maximize the entropy of the decision trees.
# - (D) To reduce the correlation between the decision trees in the ensemble.

# %% [markdown]
# **Q9.** Which of the following statements is true about nearest neighbor classifiers?
# - (A) Nearest neighbors can be slow to find in high-dimensional spaces.
# - (B) Nearest neighbor classifiers can only work with the Euclidean distance.
# - (C) Nearest neighbor classifiers do not need to store the training data.
# - (D) None of the above.

# %% [markdown]
# **Q10.** Suppose you have data with lots of outliers. Everything else being equal, and assuming that you do not do any pre-processing, what cost function will be less affected by these outliers?
# - (A) $(y - f(x))^2$
# - (B) $|y - f(x)|$
# - (C) $\frac{1}{y} \times (y - f(x))^2$
# - (D) $(\log(y) - f(x))^2$

# %% [markdown]
# **Q11.** The figure below shows three different datasets (A, B, C) and the predictions of the same linear model (the line y = x) used to predict each of them. Choose the correct ordering with respect to the MSE (Mean Squared Error) loss on each dataset:
# - (A) MSE_B > MSE_A > MSE_C
# - (B) MSE_B > MSE_C > MSE_A
# - (C) At least two of the MSE losses are equal.
# - (D) MSE_A > MSE_B > MSE_C

# %% [markdown]
# **Q12.** Considering the same figure from Q11, choose the correct ordering with respect to the MAE (Mean Absolute Error) loss on each dataset:
# - (A) MAE_A > MAE_C > MAE_B
# - (B) MAE_C > MAE_B > MAE_A
# - (C) At least two of MAE losses are equal.
# - (D) MAE_B > MAE_C > MAE_A
#
# ---

# %% [markdown]
# # Part 1: Multiple Choice Questions
#
# This part contains 12 MCQ questions worth 0.5 point each (6 points total).
#
# For each question, write the letter corresponding to the correct answer in the answer cell at the bottom.
#
# ---
#
# **Question 1** — PCA reconstruction: can you always reconstruct any data point from $P$ principal components with zero error?
#
# **Question 2** — PCA: which transformation to data matrix $\mathbf{X}$ affects the principal components?
#
# **Question 3** — Linear regression: what is the irreducible error in $p(y \mid \mathbf{x}) \sim \mathcal{N}(\beta^\top \mathbf{x} + \beta_0, \sigma^2)$?
#
# **Question 4** — Logistic regression: what are the decision boundaries of a logistic regression model?
#
# **Question 5** — Ridge vs OLS: how does the bias-variance decomposition of ridge regression compare to OLS?
#
# **Question 6** — Graph Laplacian: which eigenvector helps find a good split of a graph $G$ into two subgraphs?
#
# **Question 7** — StandardScaler: given a 2D dataset, which preprocessing result do you expect from `sklearn`'s `StandardScaler` with default parameters? *(see figure below)*
#
# **Question 8** — Random forests: why does random forests select a random subset of predictors when building each decision tree?
#
# **Question 9** — Nearest neighbor classifiers: which statement is true?
#
# **Question 10** — Outliers: which cost function is less affected by outliers?
#
# **Question 11** — MSE ordering: given three datasets A, B, C and the same linear model, choose the correct ordering of MSE losses. *(see figure below)*
#
# **Question 12** — MAE ordering: considering the same figure from Question 11, choose the correct ordering of MAE losses.

# %% [markdown]
# ---
# ## Figure for Question 7
#
# Run the cell below to generate the figure illustrating the initial dataset and four possible preprocessing results (A, B, C, D).

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler

N = 100
x1 = 4 + np.random.randn(N)
x2 = 12 * (np.random.rand(N) - 0.5)
X = np.c_[x1, x2]

fig = plt.figure(figsize=(13.0, 5.9))
ax1 = plt.subplot2grid((2,4),(0,0),rowspan=2,colspan=2)
ax1.scatter(X[:,0],X[:,1],c='C0',s=30)
ax1.set_xlabel('Feature X1'); ax1.set_ylabel('Feature X2')
ax1.set_title('Initial dataset'); ax1.set_aspect('equal')
ax1.set_xticks(np.arange(-6,7,2)); ax1.set_yticks(np.arange(-6,7,2))
ax1.set_xlim(-6,6); ax1.set_ylim(-6,6); ax1.grid(True)

ax2 = plt.subplot2grid((2,4),(0,2)); scaler=StandardScaler(); X_A=scaler.fit_transform(X)
ax2.scatter(X_A[:,0],X_A[:,1],c='C0',s=10); ax2.set_title('Preprocessing A')
ax2.set_aspect('equal'); ax2.set_xlim(-6,6); ax2.set_ylim(-6,6); ax2.grid(True)

ax3 = plt.subplot2grid((2,4),(0,3)); X_B=X-X.mean(axis=0)
ax3.scatter(X_B[:,0],X_B[:,1],c='C0',s=10); ax3.set_title('Preprocessing B')
ax3.set_aspect('equal'); ax3.set_xlim(-6,6); ax3.set_ylim(-6,6); ax3.grid(True)

ax4 = plt.subplot2grid((2,4),(1,2)); scaler=StandardScaler(); X_C=scaler.fit_transform(X); X_C=X_C+scaler.mean_
ax4.scatter(X_C[:,0],X_C[:,1],c='C0',s=10); ax4.set_title('Preprocessing C')
ax4.set_aspect('equal'); ax4.set_xlim(-6,6); ax4.set_ylim(-6,6); ax4.grid(True)

ax5 = plt.subplot2grid((2,4),(1,3)); scaler=StandardScaler(); X_D=scaler.fit_transform(X); X_D=X_D*0.5+1.0
ax5.scatter(X_D[:,0],X_D[:,1],c='C0',s=10); ax5.set_title('Preprocessing D')
ax5.set_aspect('equal'); ax5.set_xlim(-6,6); ax5.set_ylim(-6,6); ax5.grid(True)
plt.tight_layout(); plt.show()

# %% [markdown]
# **Q7 Answer**: (A) Preprocessing A
#
# `StandardScaler` subtracts the mean and divides by the standard deviation of each feature. This centers the data at zero and normalises the spread to unit variance, which matches Preprocessing A.

# %% [markdown]
# ---
# ## Figure for Questions 11 and 12
#
# Run the cell below to generate the figure showing three datasets (A, B, C) with the same linear model prediction (orange dashed line).

# %%
import matplotlib.pyplot as plt
import numpy as np

XA = [1,2,2,4,5,6,7,8]; YA = [1,2,5,4,5,6,7,8]
XB = [1,2,3,5,5,5,7,8]; YB = [1,2,3,3,5,7,7,8]
XC = [1,2,3,4,5,6,7,8]; YC = [1,3,4,5,6,5,7,8]

fig, ax = plt.subplots(1,3,figsize=(13,4))
ax[0].scatter(XA,YA,s=50,color='C0')
ax[1].scatter(XB,YB,s=50,color='C0')
ax[2].scatter(XC,YC,s=50,color='C0')
for i,axi in enumerate(ax):
    axi.grid(True); axi.plot([1,8],[1,8],color='C1',linestyle='--')
    axi.set_xticks(np.arange(1,9,1)); axi.set_yticks(np.arange(1,9,1))
    axi.set_xlabel('x (input)'); axi.set_ylabel('y (output)')
    axi.set_title(['A','B','C'][i])
plt.show()

# %% [markdown]
# ---
# ## Answers
#
# | Question | Answer |
# |----------|--------|
# | Q1  | B — Yes, if $P = d$ |
# | Q2  | B — Multiplying one of the features by a constant |
# | Q3  | A — $\sigma^2$ |
# | Q4  | B — Split classes using a combination of the input features |
# | Q5  | B — Ridge has larger bias, smaller variance |
# | Q6  | B — Eigenvector corresponding to the second-smallest eigenvalue of $L$ |
# | Q7  | A — Preprocessing A |
# | Q8  | D — To reduce the correlation between the decision trees in the ensemble |
# | Q9  | D — None of the above |
# | Q10 | B — $|y - f(x)|$ |
# | Q11 | D — $\text{MSE}_A > \text{MSE}_B > \text{MSE}_C$ |
# | Q12 | B — $\text{MAE}_C > \text{MAE}_B > \text{MAE}_A$ |

# %%
# Write your answers here (one letter per question)
answers = {
    'Q1': '',
    'Q2': '',
    'Q3': '',
    'Q4': '',
    'Q5': '',
    'Q6': '',
    'Q7': '',
    'Q8': '',
    'Q9': '',
    'Q10': '',
    'Q11': '',
    'Q12': '',
}
print(answers)
# Out:
# {'Q1': '', 'Q2': '', 'Q3': '', 'Q4': '', 'Q5': '', 'Q6': '', 'Q7': '', 'Q8': '', 'Q9': '', 'Q10': '', 'Q11': '', 'Q12': ''}
