# %% [markdown]
# # Part 2: Regression

# %% [markdown]
# Write your answers in the cells below each question.

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

# %% [markdown]
# **(a)** Set `set.seed(0)`. Simulate $6000 \times 201 = 1{,}206{,}000$ independent random variables with the standard normal distribution. Store them into a matrix, then into a data frame with 6000 rows and 201 columns. Each column is referred to as a "variable". (Useful: `rnorm`, `matrix`, `data.frame`) **(0.5 points)**

# %% [markdown]
# ### Question (a)
#
# *Your answer here.*

# %%
# Your code here

# %% [markdown]
# **(b)** Define a Gaussian multiple linear regression model using the last 200 variables to predict the first one and write a mathematical equation (no R code!) to define this regression model. Write a second mathematical equation defining the true generative model associated with the data. Compare both models and discuss. **(1 point)**

# %% [markdown]
# ### Question (b)
#
# *Your answer here.*

# %%
# Your code here

# %% [markdown]
# **(c)** Estimate the parameters of the linear model using the last 200 variables to predict the first one. Compute the number of coefficients assessed as significantly non-zero at level 5%. Comment the result. (Useful: `summary(reg)$coefficients`) **(0.5 points)**

# %% [markdown]
# ### Question (c)
#
# *Your answer here.*

# %%
# Your code here

# %% [markdown]
# **(d)** Simulate a dataset of size $N = 1000$ of the following generating model:
#
# $$X_{1,i} = \varepsilon_{1,i}$$
# $$X_{2,i} = 3X_{1,i} + \varepsilon_{2,i}$$
# $$Y_i = X_{2,i} + X_{1,i} + 2 + \varepsilon_{3,i}$$
#
# where $i \in \{1, \ldots, N\}$ and the $\varepsilon_{j,i}$ are independent $\mathcal{N}(0, 1)$ random variables. For a given $i$, what is the distribution of $(X_{1,i}, X_{2,i})$? Plot the cloud of points. What is its shape? Can you write an analytical formula for it? **(1 point)**

# %% [markdown]
# ### Question (d)
#
# *Your answer here.*

# %%
# Your code here

# %% [markdown]
# **(e)** Consider the following two regression models:
#
# $$\text{Model A:} \quad Y_i = \alpha_1 X_{1,i} + \alpha_0 + \tilde{\varepsilon}_{A,i}$$
# $$\text{Model B:} \quad Y_i = \beta_2 X_{2,i} + \beta_0 + \tilde{\varepsilon}_{B,i}$$
#
# What should be the values of $\hat{\alpha}_0$, $\hat{\alpha}_1$, $\hat{\sigma}^2_A$, $\hat{\beta}_0$, $\hat{\beta}_2$, $\hat{\sigma}^2_B$ when $N \to \infty$? Consider $N = 1000$ and check whether the estimates are close to the true values. Now do `set.seed(3)` and simulate again with $n = 10$. Estimate the parameters. What happens? **(1 point)**

# %% [markdown]
# ### Question (e)
#
# *Your answer here.*

# %%
# Your code here

# %% [markdown]
# **(f)** Consider the full model: $Y_i = \gamma_2 X_{2,i} + \gamma_1 X_{1,i} + \gamma_0 + \varepsilon_i$. For the previously simulated data with $n = 10$, estimate $\hat{\gamma}_0$, $\hat{\gamma}_1$, $\hat{\gamma}_2$, $\hat{\sigma}^2$ and compare them with the parameters from (b). What can you say about the effects of $X_1$ and $X_2$ on $Y$? And about their correlation? **(1 point)**

# %% [markdown]
# ### Question (f)
#
# *Your answer here.*

# %%
# Your code here
