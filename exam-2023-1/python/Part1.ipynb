# %% [markdown]
# # Part 1: Multiple Choice Questions

# %% [markdown]
# Write your answers in the cells below each question.

# %% [markdown]
# ### Question 1
#
# *Your answer here.*

# %% [markdown]
# ### Question 2
#
# *Your answer here.*

# %% [markdown]
# ### Question 3
#
# *Your answer here.*

# %% [markdown]
# ### Question 4
#
# *Your answer here.*
