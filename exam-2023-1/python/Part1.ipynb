# %% [markdown]
# # Part 1: Multiple Choice Questions

# %% [markdown]
# Write your answers in the cells below each question.

# %% [markdown]
# **Q1 — Robustness to outliers (1 point)**
# We consider a classification problem on linearly separable data. The dataset had an outlier — a point very far from the other datapoints. We trained LDA, logistic regression, and 1-nearest-neighbour classifiers on this dataset. We tested on a test set from the same distribution but without any outlier. After that, we removed the outlier and retrained our models.
#
# After retraining, which classifier will **not change** its decision boundary around the test points?
# - (A) Logistic regression.
# - (B) 1-nearest-neighbors classifier.
# - (C) LDA.
# - (D) None of them.

# %% [markdown]
# ### Question 1
#
# *Your answer here.*

# %% [markdown]
# **Q2 — Bias-variance decomposition (1 point)**
# Consider a regression model where data $(x, y)$ is generated by $x \in \mathbb{R}$ uniformly sampled from $[0, 1]$ and $y = x + \varepsilon$, where $\varepsilon$ is random noise with mean $0$ and variance $1$. Two models are used: model A is a trained quadratic function $g_A(x, \beta) = \beta_0 + \beta_1 x + \beta_2 x^2$ and model B is a constant function $g_B(x) = 1/2$.
#
# Compared to model B, model A has:
# - (A) Higher bias, higher variance.
# - (B) Lower bias, higher variance.
# - (C) Higher bias, lower variance.
# - (D) Lower bias, lower variance.

# %% [markdown]
# ### Question 2
#
# *Your answer here.*

# %% [markdown]
# **Q3 — Linear regression with L2-regularization (1 point)**
# Assume we are doing linear regression with mean-squared loss and L2-regularization on four one-dimensional data points. Our prediction model is $f(x) = ax + b$ and the optimization problem is:
#
# $$a^*, b^* = \arg\min \sum_{i=1}^{4} (y_i - f(x_i))^2 + \lambda a^2$$
#
# Data points $(x_i, y_i)$ are $\{(-2, 1), (-1, 3), (0, 2), (3, 4)\}$.
#
# What is the optimal value for the bias, $b^*$?
# - (A) Depends on the value of $\lambda$.
# - (B) 3
# - (C) 2.5
# - (D) None of the above answers.

# %% [markdown]
# ### Question 3
#
# *Your answer here.*

# %% [markdown]
# **Q4 — PCA (1 point)**
# Which of the following transformations to a data matrix X will affect the principal components obtained through PCA?
# - (A) Adding a constant value to all elements of X.
# - (B) Multiplying one of the features of X by a constant.
# - (C) Adding an extra feature to X (an extra column) that is constant across all data points.
# - (D) None of the above answers.

# %% [markdown]
# ### Question 4
#
# *Your answer here.*

# %% [markdown]
# **Q5 — Ridge regularization (1 point)**
# Assume $N$ training samples $(x_1, y_1), \ldots, (x_N, y_N)$ where $x_i \in \mathbb{R}^p$ and $y_i \in \mathbb{R}$. For $\lambda \geq 0$, consider:
#
# $$L_\lambda(\beta) = \frac{1}{N} \sum_{i=1}^{N} (y_i - x_i^\top \beta)^2 + \lambda \|\beta\|_2$$
#
# and let $C_\lambda = \min_{\beta} L_\lambda(\beta)$. Which statement is true?
# - (A) $C_\lambda$ is a non-increasing function of $\lambda$.
# - (B) For $\lambda = 0$, the loss $L_0$ is non-convex and might have several minimizers.
# - (C) $C_\lambda$ is a non-decreasing function of $\lambda$.
# - (D) None of the above statements are true.
#
# ### Question 5
#
# *Your answer here.*

# %% [markdown]
# **Q6 — Logistic regression (1 point)**
# Consider the logistic regression loss for binary classification with data $(x_i, y_i) \in \mathbb{R}^p \times \{0, 1\}$:
#
# $$L(\beta) = \frac{1}{N} \sum_{i=1}^{N} \left(\log(1 + e^{x_i^\top \beta}) - y_i x_i^\top \beta\right)$$
#
# Which of the following is a gradient of the loss $L$?
# - (A) $\nabla L(\beta) = \frac{1}{N} \sum_i x_i \left(\frac{e^{x_i^\top \beta}}{1 + e^{x_i^\top \beta}} - y_i x_i^\top \beta\right)$
# - (B) $\nabla L(\beta) = \frac{1}{N} \sum_i x_i \left(y_i - \frac{e^{x_i^\top \beta}}{1 + e^{x_i^\top \beta}}\right)$
# - (C) $\nabla L(\beta) = \frac{1}{N} \sum_i x_i \left(\frac{1}{1 + e^{-x_i^\top \beta}} - y_i\right)$
# - (D) None of the above.
#
# ### Question 6
#
# *Your answer here.*

# %% [markdown]
# **Q7 — Linear regression irreducible error (1 point)**
# In linear regression, we model $p(y \mid x) \sim \mathcal{N}(\beta^\top x + \beta_0, \sigma^2)$. The irreducible error in this model is:
# - (A) $\sigma^2$
# - (B) $E[y \mid x]$
# - (C) $E[(y - E[y \mid x])^2 \mid x]$
# - (D) None of the above.
#
# ### Question 7
#
# *Your answer here.*

# %% [markdown]
# **Q8 — Classifier boundary (1 point)**
# Which of these classifiers could have generated a highly non-linear, irregular decision boundary (as shown in the figure in the exam PDF)?
# - (A) Logistic regression
# - (B) 1-NN
# - (C) Quadratic discriminant analysis
# - (D) None of the above.
#
# ### Question 8
#
# *Your answer here.*
